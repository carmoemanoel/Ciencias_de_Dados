# %% [markdown]
# <a href="https://colab.research.google.com/github/carmoemanoel/Ciencias_de_Dados/blob/master/ContrachequeMagistrados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Esse Dataset tem como finalidade colocar em prática os conhecimentos adquiridos com análise de dados.

# %%
import pandas as pd

# %%
df = pd.read_csv('contracheque.csv', sep=';')
df.head()
# Out:
# <ipython-input-4-61347e315ae1>:1: DtypeWarning: Columns (1,2,3,17,18,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('contracheque.csv', sep=';')
#    cpf                                       nome  \
# 0  NaN          Aldir Guimarães Passarinho Junior
# 1  NaN                    Antonio Carlos Ferreira
# 2  NaN                   Antônio de Pádua Ribeiro
# 3  NaN  Antonio Herman de Vasconcellos e Benjamin
# 4  NaN                  Antonio Saldanha Palheiro
#
#                                       cargo  \
# 0  Ministro do Superior Tribunal de Justiça
# 1  Ministro do Superior Tribunal de Justiça
# 2  Ministro do Superior Tribunal de Justiça
# 3  Ministro do Superior Tribunal de Justiça
# 4  Ministro do Superior Tribunal de Justiça
#
#                                        lotacao  subsidio  direitos_pessoais  \
# 0                 Superior Tribunal de Justiça  32074.85               0.00
# ...

# %% [markdown]
# ##  Manipulação e limpeza de dados com pandas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161769 entries, 0 to 161768
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   cpf                               154346 non-null  object
#  1   nome                              7354 non-null    object
#  2   cargo                             7354 non-null    object
#  3   lotacao                           7351 non-null    object
#  4   subsidio                          7354 non-null    float64
#  5   direitos_pessoais                 7354 non-null    float64
#  6   indenizacoes                      7354 non-null    float64
#  7   direitos_eventuais                7354 non-null    float64
#  8   total_de_rendimentos              7354 non-null    float64
#  9   previdencia_publica               7354 non-null    float64
#  10  imposto_de_renda                  7354 non-null    float64
# ...

# %%
df.shape
# Out:
# (161769, 22)

# %%
df.columns
# Out:
# Index(['cpf', 'nome', 'cargo', 'lotacao', 'subsidio', 'direitos_pessoais',
#        'indenizacoes', 'direitos_eventuais', 'total_de_rendimentos',
#        'previdencia_publica', 'imposto_de_renda', 'descontos_diversos',
#        'retencao_por_teto_constitucional', 'total_de_descontos',
#        'rendimento_liquido', 'remuneracao_do_orgao_de_origem', 'diarias',
#        'url', 'tribunal', 'orgao', 'data_de_publicacao',
#        'mesano_de_referencia'],
#       dtype='object')

# %%
# Cria um novo dataframe sem as colunas Satélite e País.

columns = ['retencao_por_teto_constitucional', 'url',]
df.drop(columns, inplace=True, axis=1)
